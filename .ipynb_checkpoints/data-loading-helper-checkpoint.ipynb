# %%
from utilities.graphire_data_preprocessing import get_data_cube

# %%
data_cube = get_data_cube(longitude = -119.454, latitute = 50.33, data_path='Data/SeasFire.zarr')

# %%
data_cube['fcci_ba'].isel(time=450).plot()

# %%
train_data = data_cube.isel(time = slice(0, 699))

# %%
train_data
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 699, latitude: 5, longitude: 5)
# Coordinates:
#   * latitude     (latitude) float64 50.88 50.62 50.38 50.12 49.88
#   * longitude    (longitude) float64 -119.9 -119.6 -119.4 -119.1 -118.9
#     spatial_ref  int64 0
#   * time         (time) datetime64[ns] 2001-01-01 2001-01-09 ... 2016-03-05
# Data variables:
#     lst_day      (time, latitude, longitude) float32 ...
#     ndvi         (time, latitude, longitude) float32 ...
#     rel_hum      (time, latitude, longitude) float32 ...
#     ssrd         (time, latitude, longitude) float32 ...
#     sst          (time, latitude, longitude) float32 ...
#     t2m_min      (time, latitude, longitude) float32 ...
#     tp           (time, latitude, longitude) float32 ...
#     vpd          (time, latitude, longitude) float32 ...
#     fcci_ba      (time, latitude, longitude) float32 ...
# Attributes:
#     description:  The SeasFire Cube is a scientific datacube for seasonal fir...
# ...
